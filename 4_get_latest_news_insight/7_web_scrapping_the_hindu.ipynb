# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd
import time
import re

# %%
def scrap_the_hindu():
    url= 'https://www.thehindu.com/'

    r1= requests.get(url)

    r1.status_code

    coverpage= r1.content

    soup= BeautifulSoup(coverpage,'html.parser')


    all_stories = soup.find_all('div',{'class':"justIn-story"})
    length= len(all_stories)
    # length

    # all_stories[0].find('li').h3.a['href']
    # all_stories[0].find('li').a.text

    # for i in range(len(all_stories)):
    #     for j in range(len(all_stories[i])):
    #         print(all_stories[i].find_all('a')[j]['href'])


    links=[]
    titles=[]
    news=[]
    for i in range(len(all_stories)):
        for j in range(len(all_stories[i])):
            link= all_stories[i].find_all('a')[j]['href']
            if (('in' in link) and  ('pictures' in link)):
                continue
            links.append(link)
            titles.append(all_stories[i].find_all('a')[j].text)

            article = requests.get(link)
            article_content = article.content
            soup_article = BeautifulSoup(article_content, 'html.parser')
            body = soup_article.find_all('div', class_='paywall')
            content = body[0].find_all('p')

            paragraph=[]
            for x in range(0,len(content)):
                para= content[x].get_text()
                paragraph.append(para)
            news.append(' '.join(paragraph))

    df= pd.DataFrame({'links':links,'title':titles,'news':news})
    return df
df= scrap_the_hindu()
# df['title']= df['title'].str.replace(r'[0-9]{1,2}(mins|hrs)','')
# df.to_csv('data/thehindu.csv')

# %%
import time
tic= time.time()
display(scrap_the_hindu())
toc= time.time()
print('Scrapping completd in :',toc-tic,' ms')
# Out:
#                                                 links  \
# 0   https://www.thehindu.com/news/international/th...
# 1   https://www.thehindu.com/news/national/sii-to-...
# 2   https://www.thehindu.com/news/international/ce...
# 3   https://www.thehindu.com/sport/football/premie...
# 4   https://www.thehindu.com/news/national/other-s...
# 5   https://www.thehindu.com/news/national/other-s...
# 6   https://www.thehindu.com/sport/tennis/andy-mur...
# 7   https://www.thehindu.com/news/international/us...
# 8   https://www.thehindu.com/news/international/us...
# 9   https://www.thehindu.com/news/international/tu...
# 10  https://www.thehindu.com/news/international/to...
# 11  https://www.thehindu.com/news/international/br...
# 12  https://www.thehindu.com/news/international/13...
# 13  https://www.thehindu.com/news/international/br...
# 14  https://www.thehindu.com/news/international/eg...
#
#                                                 title  \
# 0   \n\n\n\n8mins\n\nThousands without power, plan...
# 1   \n\n\n\n27mins\n\nSII to launch first indigeno...
# 2   \n\n\n\n28mins\n\nCentral Africa votes in poll...
# 3   \n\n\n\n48mins\n\nPremier League | Late Wolves...
# 4   \n\n\n\n1hr\n\nLand row: Intellectuals protest...
# 5   \n\n\n\n1hr\n\nJD(U) not in favour of laws aga...
# 6   \n\n\n\n1hr\n\nAndy Murray receives Australian...
# 7   \n\n\n\n1hr\n\nU.S. government heads toward ch...
# 8   \n\n\n\n2hrs\n\nU.S. taking hard look at varia...
# 9   \n\n\n\n2hrs\n\nTurkish lawmakers pass bill mo...
# 10  \n\n\n\n2hrs\n\nTop associate of Russia’s Nava...
# 11  \n\n\n\n3hrs\n\nBritain says it will sign free...
# 12  \n\n\n\n3hrs\n\n13 detained during rallies in ...
# 13  \n\n\n\n3hrs\n\nBritish tourists sneak out of ...
# 14  \n\n\n\n4hrs\n\nEgypt delegation visits Libyan...
#
#                                                  news
# 0    Tens of thousands were left without electrici...
# 1   The first indigenous vaccine against pneumonia...
# 2    Voters went to the polls on Sunday in the Cen...
# 3    Tottenham paid for an overly conservative app...
# 4    Intellectuals of various fields on Sunday too...
# 5    At a time when BJP ruled states are making le...
# 6    Five-time Australian Open finalist Andy Murra...
# 7    The U.S. government headed toward a chaotic l...
# 8     U.S. health officials believe the coronaviru...
# 9    Turkey’s parliament approved a law Sunday tha...
# 10    A top associate of Russian opposition leader...
# 11  Britain and Turkey are set to sign a free trad...
# 12   A human rights group said that 13 people were...
# 13    Hundreds of British tourists forced into qua...
# 14   Egyptian diplomats and intelligence officials...
# Scrapping completd in : 14.531688690185547  ms

# %% [markdown]
# ## Test ____________________________________________________________

# %%
url= 'https://www.thehindu.com/'

r1= requests.get(url)
r1.status_code

coverpage= r1.content

soup= BeautifulSoup(coverpage,'html.parser')


all_stories = soup.find_all('div',{'class':"justIn-story"})
length= len(all_stories)


# links=[]
# titles=[]
# news=[]
# for i in range(len(all_stories)):
#     for j in range(len(all_stories[i])):
#         link= all_stories[i].find_all('a')[j]['href']
#         links.append(link)

#         titles.append(all_stories[i].find_all('a')[j].text)

#         article = requests.get(link)
#         article_content = article.content
#         soup_article = BeautifulSoup(article_content, 'html.parser')
#         body = soup_article.find_all('div', class_='paywall')
#         content = body[0].find_all('p')

#         paragraph=[]
#         for x in range(0,len(content)):
#             para= content[x].get_text()
#             paragraph.append(para)
#         news.append(' '.join(paragraph))

# df= pd.DataFrame({'links':links,'title':titles,'news':news})

#     return df
# df= scrap_the_hindu()
# df.to_csv('data/thehindu.csv')

# %%
# url= 'https://www.thehindu.com/'

# r1= requests.get(url)

# r1.status_code

# coverpage= r1.content

# soup= BeautifulSoup(coverpage,'html.parser')


# all_stories = soup.find_all('div',{'class':"justIn-story"})
# length= len(all_stories)
# length

# all_stories[0].find('li').h3.a['href']
# all_stories[0].find('li').a.text

# for i in range(len(all_stories)):
#     for j in range(len(all_stories[i])):
#         print(all_stories[i].find_all('a')[j]['href'])


links=[]
titles=[]
news=[]
for i in range(len(all_stories)):
    for j in range(len(all_stories[i])):
        link= all_stories[i].find_all('a')[j]['href']
        links.append(link)
        if (('in' in link) and  ('pictures' in link)):
            continue
        print(link)
        titles.append(all_stories[i].find_all('a')[j].text)
        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html.parser')
        body = soup_article.find_all('div', class_='paywall')
        content = body[0].find_all('p')

        paragraph=[]
        for x in range(0,len(content)):
            para= content[x].get_text()
            paragraph.append(para)
        news.append(' '.join(paragraph))
# Out:
# https://www.thehindu.com/news/national/other-states/336-migratory-birds-reported-dead-in-himachals-pong-dam-wildlife-sanctuary-on-wednesday/article33515003.ece
# https://www.thehindu.com/news/international/71-cases-of-new-uk-virus-mutant-strain-detected/article33515440.ece
# https://www.thehindu.com/news/national/number-of-indias-elderly-to-triple-by-2050/article33515101.ece
# https://www.thehindu.com/news/international/georgia-democrat-jon-ossoff-has-won-his-senate-runoff-election/article33515781.ece
# https://www.thehindu.com/news/national/cbi-books-six-for-duty-drawback-incentive-fraud/article33515422.ece
# https://www.thehindu.com/news/national/other-states/tour-operators-set-up-helpline-for-tourists-stranded-in-kashmir/article33513416.ece
