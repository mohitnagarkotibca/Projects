# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import numpy as np

# %%
# def get_news_theguardian():
# 2 tab right

# url definition
# url = "https://www.theguardian.com/uk"

# # Request
# r1 = requests.get(url)
# r1.status_code

# # We'll save in coverpage the cover page content
# coverpage = r1.content

# # Soup creation
# soup1 = BeautifulSoup(coverpage, 'html5lib')

# # News identification
# coverpage_news = soup1.find_all('h3', class_='fc-item__title')
# print(len(coverpage_news))
# news_contents = []
# list_links = []
# list_titles = []

# %%
def get_news_theguardian():

    # url definition
    url = "https://www.theguardian.com/uk"

    # Request
    r1 = requests.get(url)
    r1.status_code

    # We'll save in coverpage the cover page content
    coverpage = r1.content

    soup1 = BeautifulSoup(coverpage, 'html5lib')

    # News identification
    coverpage_news = soup1.find_all('h3', class_='fc-item__title')

    number_of_articles =len(coverpage_news)

    # Empty lists for content, links and titles
    # Empty lists for content, links and titles
    news_contents = []
    list_links = []
    list_titles = []
    number_of_articles= len(coverpage_news)

    for n in np.arange(0, number_of_articles):

        # We need to ignore "live" pages since they are not articles
        if "live" in coverpage_news[n].find('a')['href']:  
            continue

        # Getting the link of the article
        link = coverpage_news[n].find('a')['href']
        list_links.append(link)

        # Getting the title
        title = coverpage_news[n].find('a').get_text()
        list_titles.append(title)

        # Reading the content (it is divided in paragraphs)
        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html5lib')
        bodies = soup_article.find_all('div', class_='content__article-body from-content-api js-article__body')
        for body in bodies:
            x= body.find_all('p')
            list_paragraphs = []
            for p in np.arange(0, len(x)):
                paragraph = x[p].get_text()
                list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)

        news_contents.append(final_article)
        
    df= pd.DataFrame({'links':list_links,'title':list_titles,'news':news_contents})
    index= df['news'].drop_duplicates().index
    df= df.loc[index]        
    return df
get_news_theguardian()
# Out:
#                                                  links  \
# 0    https://www.theguardian.com/us-news/2020/oct/0...
# 4    https://www.theguardian.com/politics/2020/oct/...
# 5    https://www.theguardian.com/politics/2020/oct/...
# 6    https://www.theguardian.com/politics/2020/oct/...
# 7    https://www.theguardian.com/education/2020/oct...
# 8    https://www.theguardian.com/world/2020/oct/02/...
# 11   https://www.theguardian.com/business/2020/oct/...
# 14   https://www.theguardian.com/world/2020/oct/02/...
# 15   https://www.theguardian.com/politics/2020/oct/...
# 16   https://www.theguardian.com/world/2020/oct/02/...
# 18   https://www.theguardian.com/world/2020/oct/02/...
# 19   https://www.theguardian.com/technology/2020/oc...
# 20   https://www.theguardian.com/environment/2020/o...
# 21   https://www.theguardian.com/tv-and-radio/2020/...
# 23   https://www.theguardian.com/us-news/2020/oct/0...
# 25   https://www.theguardian.com/books/2020/oct/03/...
# 27   https://www.theguardian.com/politics/2020/oct/...
# 29   https://www.theguardian.com/commentisfree/2020...
# 31   https://www.theguardian.com/commentisfree/2020...
# 34   https://www.theguardian.com/commentisfree/2020...
# 35   https://www.theguardian.com/football/2020/oct/...
# 36   https://www.theguardian.com/sport/2020/oct/02/...
# 37   https://www.theguardian.com/sport/2020/oct/02/...
# 38   https://www.theguardian.com/football/2020/oct/...
# 40   https://www.theguardian.com/sport/2020/oct/02/...
# 42   https://www.theguardian.com/sport/2020/oct/02/...
# 44   https://www.theguardian.com/politics/2020/oct/...
# 62   Business  Trump's Covid diagnosis spooks inves...
# 70   South Park pandemic special  A biting and surp...
# 72   Bec Hill  \n\n\n  I’m slightly obsessed with B...
# 75   Sunday best  17 expert tips for the perfect ro...
# 76   'Something has to be done'  Tackling the UK's ...
# 78   Facing up to it  The most common ways we're we...
# 80   Cocktail of the week  Berenjak's amber negroni...
# 81   UK healthcare workers  Share your coronavirus ...
# 82   UK workers  Have you continued to work in the ...
# 83        NHS coronavirus app  Share your experiences
# 84   Tell us  How are you affected by local lockdow...
# 85   'Hawaii, Bristol, it's just as fun'  World's t...
# 89   'This is a nightmare'  Prayers and criticism a...
# 90   After Hong Kong  China sets sights on solving ...
# 94   Then and now  Beijing's streets during and aft...
# 103    Revelation of vast 'consulting fees' threate...
#
#                                                   news
# 0    Donald Trump’s presidency has been full of plo...
# 4    Margaret Ferrier, the MP who broke Covid rules...
# 5    Boris Johnson will demand that the increasingl...
# 6    The home secretary, Priti Patel, is under pres...
# 7    Northumbria University has said 770 of its stu...
# 8    Harvey Weinstein, the convicted rapist and imp...
# 11   Plans to open the UK’s first new deep coalmine...
# 14   The number of coronavirus cases among secondar...
# 15   When Boris Johnson barrelled into the scrum of...
# 16   Donna Burrell sits in her darkened restaurant....
# 18   Australia will allow New Zealanders to enter t...
# 19   Amazon has revealed that almost 20,000 of its ...
# 20   Sign up for monthly updates on America’s publi...
# 21   A couple of years ago, early in his time as co...
# 23   Hours after the announcement that he had teste...
# 25   Rachel Krasky has read 95 books this year. Tha...
# 27   This week the last scheduled talks were held b...
# 29   The serial incompetence of Boris Johnson’s gov...
# 31   Boris Johnson claims he is a “one nation Conse...
# 34   Donald Trump’s tax returns are a stark illustr...
# 35   The San Mamés heaved and the heavens opened. T...
# 36   The run-up to Sunday’s spectator-less Prix de ...
# 37   If life wasn’t meant to be easy, it surely has...
# 38   Premier League clubs have accepted they will h...
# 40   Honda, which supplies engines to Red Bull and ...
# 42   There was a hint of change in the damp Parisia...
# 44   Council leaders in England were given five min...
# 45   Asda has been sold to two billionaire brothers...
# 47   The founder of a leading education campaign to...
# 50   Private prosecutions should be subject to more...
# 51   Britain needs new state aid rules in order to ...
# 52   Covid-19 testing in care homes in England coul...
# 54   In grand jury testimony made public on Friday,...
# 55   Italy’s far-right former interior minister Mat...
# 57   A Syrian fighter sent into combat with Azerbai...
# 58   US voters living outside the country filed a c...
# 59   A group of intellectual Saudi Arabian expatria...
# 62   Markets in the US and Europe endured a day of ...
# 70   The great strength of South Park has always be...
# 72   Dave Allen’s sketch where Frankenstein’s monst...
# 75   Few meals retain a capacity for disappointment...
# 76   Tinuke Awe hadn’t been long at her midwife’s a...
# 78   Face masks have become a standard feature of e...
# 80   With the prevalence of negroni and white negro...
# 81   With winter approaching and coronavirus cases ...
# 82   According to a report by Alphawise research un...
# 83   After months of pilot studies, the NHS coronav...
# 84   New local lockdown restrictions are to be impo...
# 85   The rain pelted down and the wind swept in but...
# 89   Politicians and other public figures in the US...
# 90   Soon after China imposed the new national secu...
# 94   Outside a shopping mall in Beijing An ice skat...
# 103  She has tried to be the acceptable face of Tru...

# %%
# import time
# tic= time.time()
# display(get_news_theguardian())
# toc= time.time()
# print('Scrapping completd in :',toc-tic,' ms')
