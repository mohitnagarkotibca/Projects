# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd
import time
import re

# %%
def scrap_the_hindu():
    url= 'https://www.thehindu.com/'

    r1= requests.get(url)

    r1.status_code

    coverpage= r1.content

    soup= BeautifulSoup(coverpage,'html.parser')


    all_stories = soup.find_all('div',{'class':"justIn-story"})
    length= len(all_stories)
    # length

    # all_stories[0].find('li').h3.a['href']
    # all_stories[0].find('li').a.text

    # for i in range(len(all_stories)):
    #     for j in range(len(all_stories[i])):
    #         print(all_stories[i].find_all('a')[j]['href'])


    links=[]
    titles=[]
    news=[]
    for i in range(len(all_stories)):
        for j in range(len(all_stories[i])):
            link= all_stories[i].find_all('a')[j]['href']
            links.append(link)
            titles.append(all_stories[i].find_all('a')[j].text)

            article = requests.get(link)
            article_content = article.content
            soup_article = BeautifulSoup(article_content, 'html.parser')
            body = soup_article.find_all('div', class_='paywall')
            content = body[0].find_all('p')

            paragraph=[]
            for x in range(0,len(content)):
                para= content[x].get_text()
                paragraph.append(para)
            news.append(' '.join(paragraph))

    df= pd.DataFrame({'links':links,'title':titles,'news':news})
    return df
df= scrap_the_hindu()
df['title']= df['title'].str.replace(r'[0-9]{1,2}(mins|hrs)','')
df.to_csv('data/thehindu.csv')

# %%
import time
tic= time.time()
display(scrap_the_hindu())
toc= time.time()
print('Scrapping completd in :',toc-tic,' ms')

# %%
df
# Out:
#                                                 links  \
# 0   https://www.thehindu.com/news/national/tamil-n...
# 1   https://www.thehindu.com/news/national/india-g...
# 2   https://www.thehindu.com/news/international/is...
# 3   https://www.thehindu.com/business/markets/rupe...
# 4   https://www.thehindu.com/news/national/other-s...
# 5   https://www.thehindu.com/news/national/sc-refu...
# 6   https://www.thehindu.com/business/markets/sens...
# 7   https://www.thehindu.com/news/national/india-h...
# 8   https://www.thehindu.com/news/national/tamil-n...
# 9   https://www.thehindu.com/business/Industry/mah...
# 10  https://www.thehindu.com/news/national/paswan-...
# 11  https://www.thehindu.com/news/cities/chennai/p...
# 12  https://www.thehindu.com/news/national/nia-fil...
# 13  https://www.thehindu.com/news/international/wo...
# 14  https://www.thehindu.com/sport/cricket/indian-...
#
#                                                 title  \
# 0   \n\n\n\n\n\nHow the Nilgiris is battling COVID...
# 1   \n\n\n\n\n\nIndia gets second set of Swiss ban...
# 2   \n\n\n\n\n\nIslamabad High Court restrains FIA...
# 3   \n\n\n\n\n\nRupee settles 8 paise higher at 73...
# 4   \n\n\n\n\n\nCommercial vehicles start operatin...
# 5   \n\n\n\n\n\nSupreme Court refuses to stay law ...
# 6   \n\n\n\n1hr\n\nSensex rallies 327 pts post RBI...
# 7   \n\n\n\n1hr\n\nIndia has lost one of the great...
# 8   \n\n\n\n1hr\n\nClass 12 original mark certific...
# 9   \n\n\n\n1hr\n\nMahindra Holidays acquires mino...
# 10  \n\n\n\n1hr\n\nPaswan to be accorded state fun...
# 11  \n\n\n\n1hr\n\nPatients who undergo heart surg...
# 12  \n\n\n\n1hr\n\nNIA files charge sheet against ...
# 13  \n\n\n\n1hr\n\nWorld Food Programme | Five thi...
# 14  \n\n\n\n\n\nIndian Premier League 2020 | Leade...
#
#                                                  news
# 0   On October 7, 106 people tested positive, taki...
# 1    India has got the second set of Swiss bank ac...
# 2    A Pakistani court has restrained the Federal ...
# 3    The rupee strengthened by 8 paise to close at...
# 4   Assam on Friday became the first State in the ...
# 5    The Supreme Court on Friday did not pass any ...
# 6    Equity benchmark index Sensex rallied 327 poi...
# 7   Former Prime Minister Manmohan Singh on Friday...
# 8    The Directorate of Government Examinations ha...
# 9    Mahindra Holidays & Resorts India Limited (MH...
# 10  Union Minister Ram Vilas Paswan would be accor...
# 11   Sanjay, 54, V. Ramesh, 44, and M. Narmada, 70...
# 12  The National Investigation Agency (NIA) on Fri...
# 13  The UN’s World Food Programme, which won the 2...
# 14  England’s World Cup-winning captain Eoin Morga...

# %% [markdown]
# ## Test ____________________________________________________________

# %%
# def scrap_the_hindu():
# url= 'https://www.thehindu.com/'

# r1= requests.get(url)
# r1.status_code

# coverpage= r1.content

# soup= BeautifulSoup(coverpage,'html.parser')


# all_stories = soup.find_all('div',{'class':"justIn-story"})
length= len(all_stories)


links=[]
titles=[]
news=[]
for i in range(len(all_stories)):
    for j in range(len(all_stories[i])):
        link= all_stories[i].find_all('a')[j]['href']
        links.append(link)

        titles.append(all_stories[i].find_all('a')[j].text)

        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html.parser')
        body = soup_article.find_all('div', class_='paywall')
        content = body[0].find_all('p')

        paragraph=[]
        for x in range(0,len(content)):
            para= content[x].get_text()
            paragraph.append(para)
        news.append(' '.join(paragraph))

df= pd.DataFrame({'links':links,'title':titles,'news':news})

#     return df
# df= scrap_the_hindu()
# df.to_csv('data/thehindu.csv')

# %%
import pandas as pd
import re

# %%
df= pd.read_csv('data/thehindu.csv').drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                                 links  \
# 0   https://www.thehindu.com/news/national/tamil-n...
# 1   https://www.thehindu.com/news/national/india-g...
# 2   https://www.thehindu.com/news/international/is...
# 3   https://www.thehindu.com/business/markets/rupe...
# 4   https://www.thehindu.com/news/national/other-s...
# 5   https://www.thehindu.com/news/national/sc-refu...
# 6   https://www.thehindu.com/business/markets/sens...
# 7   https://www.thehindu.com/news/national/india-h...
# 8   https://www.thehindu.com/news/national/tamil-n...
# 9   https://www.thehindu.com/business/Industry/mah...
# 10  https://www.thehindu.com/news/national/paswan-...
# 11  https://www.thehindu.com/news/cities/chennai/p...
# 12  https://www.thehindu.com/news/national/nia-fil...
# 13  https://www.thehindu.com/news/international/wo...
# 14  https://www.thehindu.com/sport/cricket/indian-...
#
#                                                 title  \
# 0   \n\n\n\n33mins\n\nHow the Nilgiris is battling...
# 1   \n\n\n\n38mins\n\nIndia gets second set of Swi...
# 2   \n\n\n\n41mins\n\nIslamabad High Court restrai...
# 3   \n\n\n\n45mins\n\nRupee settles 8 paise higher...
# 4   \n\n\n\n52mins\n\nCommercial vehicles start op...
# 5   \n\n\n\n59mins\n\nSupreme Court refuses to sta...
# 6   \n\n\n\n1hr\n\nSensex rallies 327 pts post RBI...
# 7   \n\n\n\n1hr\n\nIndia has lost one of the great...
# 8   \n\n\n\n1hr\n\nClass 12 original mark certific...
# 9   \n\n\n\n1hr\n\nMahindra Holidays acquires mino...
# 10  \n\n\n\n1hr\n\nPaswan to be accorded state fun...
# 11  \n\n\n\n1hr\n\nPatients who undergo heart surg...
# 12  \n\n\n\n1hr\n\nNIA files charge sheet against ...
# 13  \n\n\n\n1hr\n\nWorld Food Programme | Five thi...
# 14  \n\n\n\n2hrs\n\nIndian Premier League 2020 | L...
#
#                                                  news
# 0   On October 7, 106 people tested positive, taki...
# 1    India has got the second set of Swiss bank ac...
# 2    A Pakistani court has restrained the Federal ...
# 3    The rupee strengthened by 8 paise to close at...
# 4   Assam on Friday became the first State in the ...
# 5    The Supreme Court on Friday did not pass any ...
# 6    Equity benchmark index Sensex rallied 327 poi...
# 7   Former Prime Minister Manmohan Singh on Friday...
# 8    The Directorate of Government Examinations ha...
# 9    Mahindra Holidays & Resorts India Limited (MH...
# 10  Union Minister Ram Vilas Paswan would be accor...
# 11   Sanjay, 54, V. Ramesh, 44, and M. Narmada, 70...
# 12  The National Investigation Agency (NIA) on Fri...
# 13  The UN’s World Food Programme, which won the 2...
# 14  England’s World Cup-winning captain Eoin Morga...
