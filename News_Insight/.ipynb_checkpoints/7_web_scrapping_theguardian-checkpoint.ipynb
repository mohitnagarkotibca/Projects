# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import numpy as np

# %%
# def get_news_theguardian():
# 2 tab right

# url definition
# url = "https://www.theguardian.com/uk"

# # Request
# r1 = requests.get(url)
# r1.status_code

# # We'll save in coverpage the cover page content
# coverpage = r1.content

# # Soup creation
# soup1 = BeautifulSoup(coverpage, 'html5lib')

# # News identification
# coverpage_news = soup1.find_all('h3', class_='fc-item__title')
# print(len(coverpage_news))
# news_contents = []
# list_links = []
# list_titles = []

# %%
def get_news_theguardian():

    # url definition
    url = "https://www.theguardian.com/uk"

    # Request
    r1 = requests.get(url)
    r1.status_code

    # We'll save in coverpage the cover page content
    coverpage = r1.content

    soup1 = BeautifulSoup(coverpage, 'html.parser')

    # News identification
    coverpage_news = soup1.find_all('h3', class_='fc-item__title')

    number_of_articles =len(coverpage_news)

    # Empty lists for content, links and titles
    # Empty lists for content, links and titles
    news_contents = []
    list_links = []
    list_titles = []
    number_of_articles= len(coverpage_news)

    for n in np.arange(0, number_of_articles):

        # We need to ignore "live" pages since they are not articles
        if "live" in coverpage_news[n].find('a')['href']:  
            continue

        # Getting the link of the article
        link = coverpage_news[n].find('a')['href']
        list_links.append(link)

        # Getting the title
        title = coverpage_news[n].find('a').get_text()
        list_titles.append(title)

        # Reading the content (it is divided in paragraphs)
        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html.parser')
        bodies = soup_article.find_all('div', class_='content__article-body from-content-api js-article__body')
        for body in bodies:
            x= body.find_all('p')
            list_paragraphs = []
            for p in np.arange(0, len(x)):
                paragraph = x[p].get_text()
                list_paragraphs.append(paragraph)
                final_article = " ".join(list_paragraphs)

        news_contents.append(final_article)
        
    df= pd.DataFrame({'links':list_links,'title':list_titles,'news':news_contents})
    index= df['news'].drop_duplicates().index
    df= df.loc[index]        
    return df

# %%
df= get_news_theguardian()
# df.to_csv('data/theguardian.csv')

# %%
# import time
# tic= time.time()
# display(get_news_theguardian())
# toc= time.time()
# print('Scrapping completd in :',toc-tic,' ms')

# %%
# Out:
#                                                links  \
# 0  https://www.theguardian.com/uk-news/2021/jul/0...
#
#                                                title  news
# 0  Exclusive  Labour lifts Trevor Phillips’ suspe...  None

# %%
# url definition
url = "https://www.theguardian.com/world/india"

# Request
r1 = requests.get(url)
r1.status_code

# We'll save in coverpage the cover page content
coverpage = r1.content

soup1 = BeautifulSoup(coverpage, 'html.parser')

# News identification
coverpage_news = soup1.find_all('h3', class_='fc-item__title')

number_of_articles =len(coverpage_news)

# Empty lists for content, links and titles
# Empty lists for content, links and titles
news_contents = []
list_links = []
list_titles = []
number_of_articles= len(coverpage_news)

for n in np.arange(0, number_of_articles):
    if "live" in coverpage_news[n].find('a')['href']:
        print('in')
        continue
    link = coverpage_news[n].find('a')['href']
    list_links.append(link)
    
    title = coverpage_news[n].find('a').get_text()
    list_titles.append(title)
    
    
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html.parser')
    bodies = soup_article.findAll('div',{'class':'dcr-185kcx9'})
    for body in bodies:
        x= body.find_all('p')
        list_paragraphs = []
        for p in np.arange(0, len(x)):
            paragraph = x[p].get_text()
            list_paragraphs.append(paragraph)
            final_article = " ".join(list_paragraphs)
    news_contents.append(final_article)

df= pd.DataFrame({'links':list_links,'title':list_titles,'news':news_contents})
index= df['news'].drop_duplicates().index
df= df.loc[index]

# %%
# len(list_links)
# list_links

# %%
# len(list_titles)
# list_titles

# %%
news_contents = []
list_links = []
list_titles = []
number_of_articles= len(coverpage_news)

for n in np.arange(0, number_of_articles):
    if "live" in coverpage_news[n].find('a')['href']:
        print('in')
        continue
    link = coverpage_news[n].find('a')['href']
    list_links.append(link)
    
    title = coverpage_news[n].find('a').get_text()
    list_titles.append(title)
    
    
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html.parser')
    bodies = soup_article.findAll('div',{'class':'dcr-185kcx9'})
    for body in bodies:
        x= body.find_all('p')
        list_paragraphs = []
        for p in np.arange(0, len(x)):
            paragraph = x[p].get_text()
            list_paragraphs.append(paragraph)
            final_article = " ".join(list_paragraphs)
    news_contents.append(final_article)

df= pd.DataFrame({'links':list_links,'title':list_titles,'news':news_contents})
index= df['news'].drop_duplicates().index
df= df.loc[index]

# %%
df
# Out:
#                                                 links  \
# 0   https://www.theguardian.com/commentisfree/2021...
# 1   https://www.theguardian.com/world/2021/jul/05/...
# 2   https://www.theguardian.com/world/2021/jul/04/...
# 3   https://www.theguardian.com/world/2021/jul/01/...
# 4   https://www.theguardian.com/science/2021/jul/0...
# 5   https://www.theguardian.com/film/2021/jul/01/m...
# 6   https://www.theguardian.com/environment/2021/j...
# 7   https://www.theguardian.com/technology/2021/ju...
# 8   https://www.theguardian.com/world/2021/jun/29/...
# 9   https://www.theguardian.com/global-development...
# 10  https://www.theguardian.com/sport/2021/jun/27/...
# 11  https://www.theguardian.com/world/2021/jun/27/...
# 12  https://www.theguardian.com/music/2021/jun/25/...
# 13  https://www.theguardian.com/global-development...
# 14  https://www.theguardian.com/global-development...
# 15  https://www.theguardian.com/sport/2021/jun/22/...
# 17  https://www.theguardian.com/world/2021/jun/19/...
# 18  https://www.theguardian.com/world/2021/jun/17/...
# 19  https://www.theguardian.com/business/2021/jun/...
#
#                                                 title  \
# 0     The Guardian view on Afghanistan withdrawal:...
# 1     Fury in India over death of 84-year-old poli...
# 2     Lessons about the legacy of Indian partition...
# 3     British rule in India: an abusive relationship
# 4     Covid ‘perfect storm’ as more patients hit b...
# 5     Why Malayalam cinema, not Bollywood, is Indi...
# 6     Five Asian countries account for 80% of new ...
# 7     Twitter in India faces criminal charges for ...
# 8   The long read  Illusions of empire: Amartya Se...
# 9     India’s Covid gender gap: women left behind ...
# 10                             Milkha Singh obituary
# 11    Global report: rise in Delta variant cases f...
# 12  Global album of the month  Arushi Jain: Under ...
# 13    ‘Drag is political’: the pioneering Indian e...
# 14    Water of death: how arsenic is poisoning rur...
# 15  The Spin  Shafali Verma shows the way for futu...
# 17    Indian athletics star Milkha Singh dies afte...
# 18    Indian boatman tells of finding baby in a bo...
# 19  Environmental investigations  Adani blasted ov...
#
#                                                  news
# 0   By bringing home US troops from Afghanistan, a...
# 1   India’s oldest political prisoner, an 84-year-...
# 2   In view of the forthcoming 74th anniversary of...
# 3   Amartya Sen has delivered a critical appraisal...
# 4   A rash of cases of a rare “black fungus” infec...
# 5   The first occurrence of Covid-19 in India was ...
# 6   Five Asian countries are jeopardising global c...
# 7   Twitter is facing criminal charges in India af...
# 8   The British empire in India was in effect esta...
# 9   Deep-rooted structural inequalities and patria...
# 10  One of India’s greatest track athletes, Milkha...
# 11  Moscow has recorded the highest Covid-19 daily...
# 12  For every raga there is a time. Traditionally,...
# 13  Two years ago, in early June 2019, a young man...
# 14  Nine members of Pankaj Rai’s family have died ...
# 15  Just as more people saw Jim Laker whistle out ...
# 17  Milkha Singh, one of India’s first sport super...
# 18  A boatman in India has rescued a 21-day-old ba...
# 19  The owners of the controversial Carmichael min...

# %%
# z=soup_article.findAll('div',{'class':'dcr-185kcx9'})
# z[0].find_all('p')[0].get_text()

# %% [markdown]
# ## Older versions

# %%
#     # We need to ignore "live" pages since they are not articles


#     # Getting the link of the article
#     link = coverpage_news[n].find('a')['href']
#     list_links.append(link)

#     # Getting the title
#     title = coverpage_news[n].find('a').get_text()
#     list_titles.append(title)

#     # Reading the content (it is divided in paragraphs)
#     article = requests.get(link)
#     article_content = article.content
#     soup_article = BeautifulSoup(article_content, 'html.parser')
#     bodies = soup_article.find_all('div', class_='content__article-body from-content-api js-article__body')
#     for body in bodies:
#         x= body.find_all('p')
#         list_paragraphs = []
#         for p in np.arange(0, len(x)):
#             paragraph = x[p].get_text()
#             list_paragraphs.append(paragraph)
#             final_article = " ".join(list_paragraphs)

#     news_contents.append(final_article)

# df= pd.DataFrame({'links':list_links,'title':list_titles,'news':news_contents})
# index= df['news'].drop_duplicates().index
# df= df.loc[index]
