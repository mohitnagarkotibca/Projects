# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import re

# %%
url='https://www.livemint.com/latest-news/'

# %%
r1= requests.get(url)
r1.status_code
# Out:
# 200

# %%
coverpage = r1.content

soup = BeautifulSoup(coverpage, 'html.parser')

# %%
coverpage_news = soup.findAll('div',{'id':'mylistView'})

# %%
container = coverpage_news[0].find_all('div',{'class':'listing clearfix impression-candidate'})

# %%
def scrap_themint():
    url='https://www.livemint.com/latest-news/'
    r1= requests.get(url)
    coverpage = r1.content
    soup = BeautifulSoup(coverpage, 'html.parser')
    coverpage_news = soup.findAll('div',{'id':'mylistView'})
    container = coverpage_news[0].find_all('div',{'class':'listing clearfix impression-candidate'})
    titles=[]
    links=[]
    news=[]
    for headline in container:
        headtag= headline.find('div',{'class':'headlineSec'})
        title= headtag.find('h2').get_text()
        link=  headline.find('div',{'class':'headlineSec'}).find('h2').a['href']
        base='https://www.livemint.com'
        url= base +link
        r= requests.get(url)
        article_content= r.content
        soup= BeautifulSoup(article_content,'html.parser')
        paragraph_list= soup.find('div',{'class':'paywall'})
        info=[]
        for para in paragraph_list.find_all('p')[:-2]:
                info.append(para.get_text())
        titles.append(title)
        links.append(link)
        news.append(' '.join(info))
    df= pd.DataFrame({'links':links,'title':titles,'news':news})
    return df

# %%
scrap_themint()
# Out:
#                                                 links  \
# 0   /news/world/oil-set-for-second-weekly-loss-on-...
# 1   /money/personal-finance/small-saving-plans-bea...
# 2   /news/world/trump-aide-hope-hicks-tests-positi...
# 3   /news/world/japan-stocks-rise-as-trading-reope...
# 4   /industry/media/google-to-pay-publishers-1-bn-...
# 5   /news/india/up-police-officer-cites-forensic-r...
# 6   /news/world/australia-s-biggest-stock-at-risk-...
# 7   /companies/start-ups/50-startups-with-ideas-of...
# 8   /companies/news/mubadala-invests-in-ril-s-reta...
# 9   /politics/policy/govt-to-implement-mega-commun...
# 10  /market/stock-market-news/-nasdaq-whale-resurf...
# 11  /auto-news/automakers-drive-into-the-fast-lane...
# 12  /news/india/gst-collections-recover-1160159997...
# 13  /news/india/gst-collections-recover-1160159901...
# 14  /industry/manufacturing/factories-hum-again-as...
# 15  /news/india/second-sero-survey-indicates-reduc...
# 16  /news/india/h1-b-visa-trump-blocked-from-restr...
# 17  /industry/retail/businesses-explore-new-delive...
# 18  /news/india/india-china-working-to-keep-truce-...
# 19  /market/stock-market-news/exchange-outage-is-l...
#
#                                                 title  \
# 0   Oil set for second weekly loss on deterioratin...
# 1                Small saving plans beat bank FD rate
# 2   Trump aide Hope Hicks tests positive for coron...
# 3    Japan stocks rise as trading reopens post outage
# 4                      Google to pay publishers $1 bn
# 5   UP police officer cites forensic report, says ...
# 6   Australia’s biggest stock at risk from Sanofi,...
# 7                    50 startups with ideas of Gandhi
# 8                Mubadala invests in RIL’s retail arm
# 9   Govt to implement mega communication network p...
# 10  'Nasdaq whale' resurfaces as Facebook, Amazon ...
# 11                Automakers drive into the fast lane
# 12                            GST collections recover
# 13                            GST collections recover
# 14       Factories hum again as output expands in Sep
# 15  Second sero survey indicates reduction in infe...
# 16  H1-B visa: Trump blocked from restricting visa...
# 17            Businesses explore new delivery options
# 18  India, China working to keep truce but uncerta...
# 19  Exchange outage is latest blow to Tokyo’s fina...
#
#                                                  news
# 0   Futures in New York fell toward $38 a barrel F...
# 1   A one-year fixed deposit (FD) with State Bank ...
# 2   There was no indication that the president has...
# 3   Shares in Tokyo opened higher, while those in ...
# 4   The company has set aside more than $1 billion...
# 5   "The report of the FSL has come. It says clear...
# 6   Biotechnology firm CSL Ltd., which makes thera...
# 7   More than a century- and-a-half after Gandhi’s...
# 8   The investment values Reliance Retail Ventures...
# 9   The project will be rolled out by government-o...
# 10  Amazon.com Inc., Facebook Inc. and Netflix Inc...
# 11  Maruti Suzuki India Ltd, Hyundai Motor India L...
# 12  GST collections of the central and state gover...
# 13  GST collections of the central and state gover...
# 14  Manufacturing output expanded to its highest l...
# 15  It indicates that infection spread in slums in...
# 16  White said his order doesn’t apply nationwide ...
# 17  Delhi-based on-demand delivery service Pidge h...
# 18  Both countries are looking to schedule a new r...
# 19  As China clamps down further on Hong Kong, som...
